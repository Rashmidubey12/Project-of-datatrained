# %% [markdown]
# ## Red wine quality

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("winequality-red.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# # scatterplot

# %%
import seaborn as sns
sns.scatterplot(x="fixed acidity",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x="volatile acidity",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %%
sns.scatterplot(x="citric acid",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='quality'>

# %%
sns.scatterplot(x="residual sugar",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='quality'>

# %%
sns.scatterplot(x="chlorides",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='quality'>

# %%
sns.scatterplot(x="free sulfur dioxide",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x="total sulfur dioxide",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %%
sns.scatterplot(x="density",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='density', ylabel='quality'>

# %%
sns.scatterplot(x="pH",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='quality'>

# %%
sns.scatterplot(x="sulphates",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='quality'>

# %%
sns.scatterplot(x="alcohol",y= "quality",data=df)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='quality'>

# %% [markdown]
# ## correlation

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.corr()['quality'].sort_values()
# Out:
# volatile acidity       -0.390558
# total sulfur dioxide   -0.185100
# density                -0.174919
# chlorides              -0.128907
# pH                     -0.057731
# free sulfur dioxide    -0.050656
# residual sugar          0.013732
# fixed acidity           0.124052
# citric acid             0.226373
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %% [markdown]
# # correlaiton using heatmap

# %%
import matplotlib.pyplot as plt
#size of canvas
plt.figure(figsize=(23,11))
sns.heatmap(df.corr(), annot=True ,linewidths= 0.5, linecolor="black", fmt = ' .2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## outcome of correlation:

# %% [raw]
# max correlaion : alcohol
# min correlation :volatile acidity

# %% [markdown]
# ## Describing Datasets:

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
plt.figure(figsize=(23,18))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth=2,annot=True,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variable summary")
plt.show()

# %% [markdown]
# ## outcome of describe of datasets

# %% [markdown]
# from the above plotting we are determining mean, standard deviation,minimum and maximum value of each column. it helps us further in data cleaning.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# ## outliers checking:

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
collist=df.columns.values
ncol=30
nrows=14
plt.figure(figsize=(ncol,3*ncol))
for i in range (0,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
# ## skewness:

# %%
df.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# dtype: float64

# %% [markdown]
# ## Normal Distribution Curve:

# %%
sns.distplot(df["fixed acidity"])
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
sns.distplot(df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
sns.distplot(df["citric acid"])
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(df["residual sugar"])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(df["chlorides"])
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
sns.distplot(df["free sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["total sulfur dioxide"])
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
sns.distplot(df["density"])
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %%
sns.distplot(df["pH"])
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %%
sns.distplot(df["sulphates"])
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
sns.distplot(df["alcohol"])
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# ## The normal distribution shows that the data is skewed.

# %% [markdown]
# # Data cleaning:

# %%
df.corr()['quality']
# Out:
# fixed acidity           0.124052
# volatile acidity       -0.390558
# citric acid             0.226373
# residual sugar          0.013732
# chlorides              -0.128907
# free sulfur dioxide    -0.050656
# total sulfur dioxide   -0.185100
# density                -0.174919
# pH                     -0.057731
# sulphates               0.251397
# alcohol                 0.476166
# quality                 1.000000
# Name: quality, dtype: float64

# %%
delete=pd.DataFrame([["-0.390558","volatile acidity","No","Alot"],["0.226373","citric acid","No","Alot"]],columns=["correlation with target","column name","normalised","outliers"])
delete
# Out:
#   correlation with target       column name normalised outliers
# 0               -0.390558  volatile acidity         No     Alot
# 1                0.226373       citric acid         No     Alot

# %%
df=df.drop(["volatile acidity","citric acid"],axis=1)

# %%
df
# Out:
#       fixed acidity  residual sugar  chlorides  free sulfur dioxide  \
# 0               7.4             1.9      0.076                 11.0
# 1               7.8             2.6      0.098                 25.0
# 2               7.8             2.3      0.092                 15.0
# 3              11.2             1.9      0.075                 17.0
# 4               7.4             1.9      0.076                 11.0
# ...             ...             ...        ...                  ...
# 1594            6.2             2.0      0.090                 32.0
# 1595            5.9             2.2      0.062                 39.0
# 1596            6.3             2.3      0.076                 29.0
# 1597            5.9             2.0      0.075                 32.0
# 1598            6.0             3.6      0.067                 18.0
#
#       total sulfur dioxide  density    pH  sulphates  alcohol  quality
# 0                     34.0  0.99780  3.51       0.56      9.4        5
# ...

# %% [markdown]
# ## Removing outliers:

# %% [markdown]
# z-score Technique:

# %%
from scipy.stats import zscore
import numpy as np
z= np.abs(zscore(df))
z.shape
# Out:
# (1599, 10)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   42,   43,   45,
#          57,   81,   81,   83,   86,   88,   91,   92,   95,  106,  106,
#         109,  142,  144,  147,  151,  151,  151,  163,  164,  169,  169,
#         181,  226,  226,  240,  243,  244,  258,  258,  274,  281,  291,
#         324,  325,  339,  340,  347,  354,  374,  381,  391,  396,  396,
#         400,  400,  442,  442,  451,  459,  467,  480,  480,  494,  515,
#         517,  544,  554,  554,  555,  555,  557,  557,  568,  584,  588,
#         591,  595,  608,  614,  636,  639,  649,  649,  651,  652,  652,
#         652,  672,  684,  690,  692,  692,  695,  723,  730,  754,  776,
#         777,  795,  821,  832,  836,  837,  889,  899,  911,  917,  923,
#         925,  926,  982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079,
#        1079, 1081, 1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231,
#        1235, 1244, 1244, 1244, 1260, 1269, 1269, 1270, 1270, 1288, 1289,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (1599, 10)
# (1458, 10)

# %%
len(np.where(z>3)[0])
# Out:
# 181

# %% [markdown]
# ## Percentage data loss:

# %%
loss_percent=(1599-1458)/1599*100
print(loss_percent)
# Out:
# 8.818011257035648

# %% [markdown]
# ## Model without outliers is df and model with desired outliers is df_new1:

# %% [markdown]
# #Dividing data in features and vectros:

# %%
# independent column/features
x=df_new.iloc[:,:-1]
# target
y=df_new.iloc[:,-1]

# %% [markdown]
# ## Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.46531304, -0.60699518, -0.14634882, ...,  1.35472616,
#         -0.58214208, -1.12084644],
#        [-0.16806727,  0.65224299,  0.9800568 , ..., -0.82077427,
#          0.45668225, -0.53203934],
#        [-0.16806727,  0.21101302,  0.71361855, ..., -0.38617329,
#          0.22572251, -0.53203934],
#        ...,
#        [-1.44922717,  0.21101302, -0.14634882, ...,  0.74054165,
#          0.93435865,  0.74129668],
#        [-1.88412706, -0.37111918, -0.20837986, ...,  1.7567213 ,
#          0.67127261, -0.03633508],
#        [-1.77077959,  1.5464447 , -0.74538744, ...,  0.5327437 ,
#          0.30462192,  0.74129668]])

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.46531304, -0.60699518, -0.14634882, ...,  1.35472616,
#         -0.58214208, -1.12084644],
#        [-0.16806727,  0.65224299,  0.9800568 , ..., -0.82077427,
#          0.45668225, -0.53203934],
#        [-0.16806727,  0.21101302,  0.71361855, ..., -0.38617329,
#          0.22572251, -0.53203934],
#        ...,
#        [-1.44922717,  0.21101302, -0.14634882, ...,  0.74054165,
#          0.93435865,  0.74129668],
#        [-1.88412706, -0.37111918, -0.20837986, ...,  1.7567213 ,
#          0.67127261, -0.03633508],
#        [-1.77077959,  1.5464447 , -0.74538744, ...,  0.5327437 ,
#          0.30462192,  0.74129668]])

# %% [markdown]
# ## since the outcome has only two variable we will use binary classification model.

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Splitting the dataframe:

# %%
for i in range(0,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round (accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i,"the model performs very well")
        print("At random state:-",i)
        print("Training r2_score is :-",accuracy_score(y_train,pred_train)*100)
        print("Training r2_score is :-",accuracy_score(y_test,pred_test)*100)
# Out:
# At random state 320 the model performs very well
# At random state:- 320
# Training r2_score is :- 59.86277873070326
# Training r2_score is :- 59.93150684931506
# At random state 459 the model performs very well
# At random state:- 459
# Training r2_score is :- 59.86277873070326
# Training r2_score is :- 59.93150684931506
# At random state 515 the model performs very well
# At random state:- 515
# Training r2_score is :- 59.94854202401372
# Training r2_score is :- 59.93150684931506
# At random state 578 the model performs very well
# At random state:- 578
# Training r2_score is :- 60.291595197255575
# Training r2_score is :- 60.273972602739725
# At random state 598 the model performs very well
# At random state:- 598
# Training r2_score is :- 59.94854202401372
# Training r2_score is :- 59.93150684931506
# At random state 626 the model performs very well
# At random state:- 626
# Training r2_score is :- 60.97770154373928
# Training r2_score is :- 60.95890410958904
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=903)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00        10
#            5       0.33      0.38      0.35       117
#            6       0.40      0.45      0.43       126
#            7       0.05      0.03      0.04        36
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.35       292
#    macro avg       0.16      0.17      0.16       292
# weighted avg       0.31      0.35      0.33       292

# %% [markdown]
# ## cross validation score for logistic regression

# %%
pred_lr = lr.predict(x_test)
from sklearn.model_selection import cross_val_score
lss = accuracy_score(y_test,pred_lr)
for j in range(2,10):
    lsscore = cross_val_score(lr,x,y,cv=j)
    lsc = lsscore.mean()
    print("At cv:-",j)
    print("cross validation score is:-",lsc*100)
    print("accuracy_score is :-",lss*100)
    print("\n")
# Out:
# At cv:- 2
# cross validation score is:- 55.41838134430728
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 3
# cross validation score is:- 58.230452674897116
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 4
# cross validation score is:- 58.57613277133825
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 5
# cross validation score is:- 57.61380219366379
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 6
# cross validation score is:- 59.465020576131685
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 7
# cross validation score is:- 58.23354277301645
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 8
# cross validation score is:- 58.715396625232685
# accuracy_score is :- 62.671232876712324
#
#
# At cv:- 9
# cross validation score is:- 58.64197530864198
# accuracy_score is :- 62.671232876712324

# %%
lsscore_selected = cross_val_score(lr,x,y,cv=6).mean()
print("the cv score is:-", lsscore_selected,"\nthe accuracy score is: ",lss)
# Out:
# the cv score is:- 0.5946502057613169
# the accuracy score is:  0.6267123287671232

# %% [markdown]
# ## mode saving:

# %%
import pickle
filename='winequality_diabetes.pkl'
pickle.dump(lr,open(filename,'wb'))

# %% [markdown]
# ## conclusion:

# %%
import numpy as np
a=np.array(y_test)
predicted=np.array(lr.predict(x_test))
df_com=pd.DataFrame({"original":a,"predicted":predicted}, index= range(len(a)))
df_com
# Out:
#      original  predicted
# 0           6          5
# 1           6          5
# 2           6          6
# 3           5          5
# 4           5          6
# ..        ...        ...
# 287         5          5
# 288         5          5
# 289         6          6
# 290         6          6
# 291         6          6
#
# [292 rows x 2 columns]
